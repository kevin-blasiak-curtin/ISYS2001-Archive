# %% [markdown]
# <a href="https://colab.research.google.com/github/kevin-blasiak-curtin/ISYS2001-Archive/blob/main/Module%2003%20-%20Making%20Computers%20Think/lab_ticket_budget_decisions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 3 Lab Ticket: Budget Decisions
#
# This is your lab ticket for the week. Unlike the worksheet, I am not going to hold your hand here. You get a rough brief, and you design and build the solution yourself. That is the whole point: to see whether you can take the decision-making patterns from the worksheet and apply them to a problem no one has spelled out for you.
#
# ## What to submit
#
# 1. Build your solution in this notebook.
# 2. Make sure your code runs top to bottom without errors.
# 3. Download it as a `.ipynb` file (in Colab: File > Download > Download .ipynb).
# 4. Submit it as your Week 3 lab ticket.
#
# Keep it honest. Use AI as a thinking partner if you like, but the design decisions should be yours, and you should be able to explain every line.

# %% [markdown]
# ## The brief
#
# Build a tool that helps someone make a smart budget decision.
#
# That is deliberately loose. You decide what a "smart budget decision" means and who it is for. A few directions you could take it, though you are not limited to these:
#
# - An expense classifier that sorts spending into categories and reacts to each.
# - A budget checker that warns when an expense is too big a share of someone's budget.
# - A savings goal tracker that gives different feedback depending on progress.
# - A purchase advisor that weighs the price against how much money and income the person has, then gives advice.
#
# Pick one, or invent your own. The only hard requirement is that your program makes genuinely different decisions depending on the numbers it is given.

# %% [markdown]
# ## Step 1: Design before you code
#
# Do this in the text cell below, before you touch any Python.
#
# - What is your tool for, in one sentence?
# - What inputs does it need from the user?
# - What are the decision points, and what thresholds will you use?
# - What should it say or do in each case?
#
# Think about the boundaries too. What happens at exactly the threshold? What if someone enters 0, or a huge number?

# %% [markdown]
# > **Your design** (double-click to edit):
#
# ```
# What it does:
#
# Inputs:
#
# Decision rules (rough is fine):
#
# Edge cases to handle:
# ```

# %% [markdown]
# ## Step 2: Build it
#
# Write your solution in the cell below. Start simple and get one decision working before you add more. You can use `input()` to collect values and `if/elif/else` to make the calls.

# %%
# Your budget decision tool
# Tip: collect the numbers with input() and float(), then let your if/elif/else decide.

# %% [markdown]
# ## Step 3: Test it
#
# Run your program with a few different inputs and check it behaves the way you designed. Include at least one case near a threshold and one obvious case, then note briefly what you tried.

# %% [markdown]
# > **What you tested** (double-click to edit):
#
# ```
# Test 1 (input, expected, actual):
#
# Test 2:
#
# Test 3 (a borderline case):
# ```

# %% [markdown]
# ## Quick reflection
#
# > Double-click to answer. A sentence or two each is plenty.
#
# 1. Why did you choose the thresholds you did?
# 2. What was the trickiest decision to get right in code?
# 3. If you kept building this, what would you add next?

# %% [markdown]
# ## Before you submit
#
# - [ ] Your code runs top to bottom with no errors.
# - [ ] The program makes different decisions for different inputs.
# - [ ] You can explain every line if asked.
# - [ ] You have answered the reflection.
# - [ ] You have downloaded the notebook and submitted it as your Week 3 lab ticket.
#
# This mini-project is the first brick in a bigger wall. Over the semester your budget logic will grow into a finance tracker: loops to handle many transactions, saved data, and eventually some AI smarts. What you design today is worth keeping.
